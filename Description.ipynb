# %% [markdown]
# Импорт необходимых для работы библиотек
#
# Формат вывода массивов чисел с плавающей точкой - 2 знака после запятой
#
# Игнорировать некритические предупреждения

# %% [markdown]
# Задать функцию static_calc, принимающую на вход численные значения:
# * B
# * n
# * $H_t$
# * d
# * D
# * допускаемое напряжение $\sigma_z$ в точке А
#
# Строку, определяющую тип результатов, возвращаемых функцией
#
# Логические значения: выводить ли начальные данные/промежуточные значения/подробные результаты/графики на экран

# %% [markdown]
# Внутри функции:
#
# Задать константы
# Вычислить производные исходные данные
#
# Найти геометрические характеристики
#
# Если print_init == True вывести на экран исходные данные и геометрические характеристики
#
# Найти вес элементов конструкции и моменты этих сил
#
# Если print_var == True вывести на экран значения весов и моментов
#
# Найти значения остальных нагрузок и моментов
#
# Если print_var == True вывести на экран значения этих нагрузок и их моментов
#
# Найти сумму сил и моментов для строительного периода - только собственный вес и его
#
# Если print_results == True вывести на экран значения суммарной нагрузки с пометкой строительный период
#
# Найти сумму сил и моментов для эксплуатационного периода
#
# Если print_results == True вывести на экран значения суммарной нагрузки с пометкой эксплуатационный период
#
# Вычислить критерии отсутствия растягивающих напряжений и устойчивости
#
# Если print_results == True вывести на экран эти критерии
#
# Задать массив координат Х
#
# Найти массив значений напряжений $\sigma_z$ и значения в крайних точках сечения
#
# Найти значения $\sigma_x$ в крайних точках сечения
#
# Найти массив значений ширины сечения в зависимости от координаты х
#
# Найти массив значений напряжений $\sigma_x$
#
# Найти значения $\tau_{xz}$ в крайних точках сечения
#
# Найти массив значений слагаемого $\tilde{\tau_{xz}}$ в зависимости от координаты х, аналогично $\sigma_x$
#
# Найти массив значений множителей для слагаемого $\Delta \tau_{xz}$ по участкам в зависимости от координаты х
#
# Найти массив слагаемых $\Delta \tau_{xz}$
#
# Найти массив $\tau_{xz}$
#
# Найти массив предельных  $\tau_{xz,lim}$
#
# Проверить в каждой точке, не превышают ли значения  $\tau_{xz}$ предельных
#
# Найти массив значений $\sigma_{1,2}$
#
# Если print_results == True вывести на экран все получившиеся массивы и результат проверки, не превышают ли касательные напряжения критических значений
#
# Если plots == True на основании массива координат и массивов значений напряжений построить 4 эпюры
#
# Определить, какие данные будет возвращать функция для дальнейшего их использования во внешней программе

# %% [markdown]
# Задать функцию plot_bn, принимающую на вход численное значение высоты плотины
#
# Задать массивы B и n в заданных промежутках, заполненные числами с определенным шагом
#
# Задать массив для значений B полученных интерполяцией
#
# Задать большой массив для хранения значений критериев, возвращаемых функцией static calc
#
# В цикле перебирать каждое значение n из массива:
#
# Во вложенном цикле перебирать каждое значение B из массива:
#
# Для текущих B и n с помощью функции static calc вычислить критерии отсутствия растягивающих напряжений и устойчивости
#
# Для критерия устойчивости: если текущее значение больше нуля, а предыдущее меньше т.е. есть переход через ноль, найти значение B максимально приближающее критерий устойчивости к нулю с помощью интерполяции
#
# То же самое для критерия отсутствия растягивающих напряжений
#
# Записать полученное интерполяцией значение B в заданный для этого массив
#
# Построить график - на оси х массив значений n, на оси у полученные интерполяцией значения B

# %% [markdown]
# Задать функцию ht_plot, не принимающую на вход параметры
#
# Задать массивы со значениями высот плотины, найденных по графикам оптимальных значений B и n
#
# Построить по этим массивам графики
